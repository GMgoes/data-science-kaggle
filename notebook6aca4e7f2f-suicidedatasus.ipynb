# %% [markdown]
# <a href="https://www.kaggle.com/code/gmgoes/notebook6aca4e7f2f-suicidedatasus?scriptVersionId=135271163" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
#Libraries
from collections import Counter
from statistics import mean;
import seaborn as sns
import pandas as pd;
import numpy as np;
import os;
print('OK');
# Out:
# OK

# %%
# Getting the dataset
data = pd.read_csv('/kaggle/input/dados-de-suicdio-no-brasil-2014-a-2018/datasus_suicidio_2014_2018.csv', encoding='iso-8859-1');
print('OK')
# Out:
# OK

# %%
# Histogram and density chart visualization
# data['idade'].hist();
# data['idade'].hist(bins = 10);
# data['idade'].hist(bins = 50);
# data['idade'].hist(bins = 100);
# data['idade'].plot(kind='density');
# sns.distplot(data['idade']); # Deprecated - histplot() and displot()

# %%
# Boxplot visualization
print(sorted(Counter(data['idade']).items()));
#sns.boxplot(x = 'idade', data = data);
#sns.scatterplot(data = data['idade'])
# Out:
# [(9.0, 9), (10.0, 12), (12.0, 66), (13.0, 186), (14.0, 289), (15.0, 435), (16.0, 571), (17.0, 756), (18.0, 854), (19.0, 977), (20.0, 1089), (21.0, 1139), (22.0, 1123), (23.0, 1099), (24.0, 1107), (25.0, 1182), (26.0, 1135), (27.0, 1157), (28.0, 1190), (29.0, 1231), (30.0, 1272), (31.0, 1267), (32.0, 1238), (33.0, 1283), (34.0, 1228), (35.0, 1262), (36.0, 1190), (37.0, 1210), (38.0, 1236), (39.0, 1245), (40.0, 1180), (41.0, 1167), (42.0, 1102), (43.0, 1066), (44.0, 1052), (45.0, 1069), (46.0, 1059), (47.0, 1078), (48.0, 995), (49.0, 978), (50.0, 1063), (51.0, 1011), (52.0, 953), (53.0, 998), (54.0, 953), (55.0, 898), (56.0, 859), (57.0, 830), (58.0, 814), (59.0, 749), (60.0, 712), (61.0, 631), (62.0, 654), (63.0, 601), (64.0, 593), (65.0, 506), (66.0, 522), (67.0, 515), (68.0, 495), (69.0, 441), (70.0, 471), (71.0, 392), (72.0, 368), (73.0, 332), (74.0, 341), (75.0, 303), (76.0, 318), (77.0, 228), (78.0, 268), (79.0, 250), (80.0, 223), (82.0, 160), (83.0, 143), (84.0, 154), (85.0, 106
# ...

# %% [markdown]
# ### TODO:
# - Do Parallel Cordinate plot visualization
# - Do Boxplot plot visualization
# - Do Violin plot visualization
# - Do Z-Score plot visualization
# - Do Heatmap plot visualization
# - Do Histogramas plot visualization
# - Do Scatter plot visualization

# %% [markdown]
# References: <br>
# https://medium.com/psicodata/simples-e-direto-um-guia-de-visualizacao-de-dados-com-python-7d39c95ca343 <br>
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.hist.html <br>
# https://seaborn.pydata.org/generated/seaborn.distplot.html <br>
# https://medium.com/data-hackers/tratamento-e-transforma%C3%A7%C3%A3o-de-dados-nan-uma-vis%C3%A3o-geral-e-pr%C3%A1tica-54efa9fc7a98
